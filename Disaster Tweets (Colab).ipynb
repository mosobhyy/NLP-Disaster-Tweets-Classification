# %% [markdown]
# <a id="top"></a> <br>
#
# # Table of Contents
#
# > [1. Import Libraries](#1)
# >
# > [2. Load Data](#2)
# >
# > [3. Data Splitting](#3)
# >
# > [4. Text Preprocessing](#4)
# >
# > [5. Model](#5)
# >
# > * [5.1 BOW](#5.1)
# >
# >  * [5.1.1 Text Preparation for BOW](#5.1.1)
# >
# >  * [5.1.2 Building Model](#5.1.2)
# >
# >  * [5.1.3 Training VS Validation](#5.1.3)
# >
# >  * [5.1.4 Save Model](#5.1.4)
# >
# >  * [5.1.5 Save Performance](#5.1.5)
# >
# > * [5.2 BOW Vectors](#5.2)
# >
# >  * [5.2.1 Building Model](#5.2.1)
# >
# >  * [5.2.2 Training VS Validation](#5.2.2)
# >
# >  * [5.2.3 Save Model](#5.2.3)
# >
# >  * [5.2.4 Save Performance](#5.2.4)
# >
# > * [5.3 LSTM](#5.3)
# >
# >  * [5.3.1 Building Model](#5.3.1)
# >
# >  * [5.3.2 Training VS Validation](#5.3.2)
# >
# >  * [5.3.3 Save Model](#5.3.3)
# >
# >  * [5.3.4 Save Performance](#5.3.4)
# >
# > * [5.4 GRU](#5.4)
# >
# >  * [5.4.1 Building Model](#5.4.1)
# >
# >  * [5.4.2 Training VS Validation](#5.4.2)
# >
# >  * [5.4.3 Save Model](#5.4.3)
# >
# >  * [5.4.4 Save Performance](#5.4.4)
# >
# > [6. Evaluation](#6)
# >
# > [7. Submission File Generation](#7)

# %% [markdown]
# <a id="1"></a> <br>
# # 1. Import Libraries

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from tensorflow.keras.preprocessing.text import Tokenizer  
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from collections import Counter
from pathlib import Path
import os
import numpy as np
import re
import string
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.corpus import wordnet
import unicodedata
import html
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# <a id="2"></a> <br>
#
# # 2. Download Data
# ([Go to top](#top))

# %%
# username = 'mosobhy'
# key = ''

# if '.kaggle' not in os.listdir('/root'):
#   !mkdir ~/.kaggle

# !touch ~/.kaggle/kaggle.json
# !chmod 666 ~/.kaggle/kaggle.json

# with open('/root/.kaggle/kaggle.json', 'w') as file:
#   file.write('{"username":"%s","key":"%s"}' % (username, key))

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !cat ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c nlp-getting-started

# %%
# !unzip /content/nlp-getting-started.zip -d /content/
# !rm /content/nlp-getting-started.zip

# %% [markdown]
# <a id="3"></a> <br>
#
# # 3. Load Data
# ([Go to top](#top))

# %%
train_df = pd.read_csv('/content/train.csv')
train_df.shape
# Out:
# (7613, 5)

# %%
train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# For training our deep learning model, we will use the 'text' column as our input feature or `X_train`, and the 'target' column as our output or `y_train`. Any other columns that are not required will be dropped as we are only interested in the 'text' column.

# %%
X_train_raw = train_df['text'].values

# %%
X_train_raw.shape
# Out:
# (7613,)

# %%
X_train_raw[5]
# Out:
# '#RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires'

# %%
_ = list(map(print, X_train_raw[:5]+'\n'))
# Out:
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
#
# Forest fire near La Ronge Sask. Canada
#
# All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
#
# 13,000 people receive #wildfires evacuation orders in California
#
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school

# %%
y_train = train_df['target'].values

# %%
y_train.shape
# Out:
# (7613,)

# %%
y_train[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %% [markdown]
# <a id="4"></a> <br>
#
# # 4. Data Splitting
# ([Go to top](#top))

# %% [markdown]
# As we see there's a little bit class imbalance, so we'll use `stratify` parameter with `train_test_split`.

# %%
_ = sns.countplot(x=y_train)

# %%
from sklearn.model_selection import train_test_split

X_train_raw, X_validation_raw, y_train, y_validation = train_test_split(X_train_raw, y_train, test_size=0.2, stratify=y_train)

print(X_train_raw.shape)
print(y_train.shape)
print()
print(X_validation_raw.shape)
print(y_validation.shape)
# Out:
# (6090,)
# (6090,)
#
# (1523,)
# (1523,)

# %% [markdown]
# <a id="5"></a> <br>
#
# # 5. Text Preprocessing
# ([Go to top](#top))
#
# In this phase, we apply some operations on the text, to make it in the most usable form for the task at hand. Mainly we clean it up to be more appealing to the problem we try to solve. The input is __text__ and the output is a transformed __text__.

# %%
def remove_special_chars(text):
    re1 = re.compile(r'  +')
    x1 = text.lower().replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>', 'u_n').replace(' @.@ ', '.').replace(
        ' @-@ ', '-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x1))


def remove_non_ascii(text):
    """Remove non-ASCII characters from list of tokenized words"""
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')


def to_lowercase(text):
    return text.lower()



def remove_punctuation(text):
    """Remove punctuation from list of tokenized words"""
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)


def replace_numbers(text):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    return re.sub(r'\d+', '', text)


def remove_whitespaces(text):
    return text.strip()


def remove_stopwords(words, stop_words):
    """
    :param words:
    :type words:
    :param stop_words: from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
    or
    from spacy.lang.en.stop_words import STOP_WORDS
    :type stop_words:
    :return:
    :rtype:
    """
    return [word for word in words if word not in stop_words]


def stem_words(words):
    """Stem words in text"""
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in words]

def lemmatize_words(words):
    """Lemmatize words in text"""

    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(word) for word in words]

def lemmatize_verbs(words):
    """Lemmatize verbs in text"""

    lemmatizer = WordNetLemmatizer()
    return ' '.join([lemmatizer.lemmatize(word, pos='v') for word in words])

def text2words(text):
  return word_tokenize(text)

def normalize_text(text):
    text = remove_special_chars(text)
    text = remove_non_ascii(text)
    text = remove_punctuation(text)
    text = to_lowercase(text)
    text = replace_numbers(text)
    words = text2words(text)
    words = remove_stopwords(words, stop_words)
    #words = stem_words(words)# Either stem ovocar lemmatize
    words = lemmatize_words(words)
    words = lemmatize_verbs(words)

    return ''.join(words)

# %%
X_train_clean = X_train_raw.copy()
X_validation_clean = X_validation_raw.copy()

X_train_clean = list(map(normalize_text, X_train_clean))
X_validation_clean = list(map(normalize_text, X_validation_clean))

# X_train_clean

# %% [markdown]
# <a id="6"></a> <br>
#
# # 6. Model
# ([Go to top](#top))

# %%
evaluation_df = pd.DataFrame()
models_dict = {}

# %% [markdown]
# <a id="6.1"></a> <br>
# ## 6.1 BOW

# %% [markdown]
# <a id="6.1.1"></a> <br>
#
# ##### Text Preparation for BOW

# %%
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(X_train_clean)
X_validation = vectorizer.transform(X_validation_clean)

# %%
# vectorizer.vocabulary_

# %%
X_train = X_train.toarray()
X_validation = X_validation.toarray()

# %%
print(X_train.shape)
print(X_validation.shape)
# Out:
# (6090, 16172)
# (1523, 16172)

# %% [markdown]
# <a id="6.1.2"></a> <br>
#
# ##### Building Model

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                258768
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 259,057
# Trainable params: 259,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model)

# %%
from keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1
label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# <a id="6.1.4"></a> <br>
#
# ##### Save Model

# %%
model.save('/content/bow.h5')

# %% [markdown]
# <a id="6.1.5"></a> <br>
#
# ##### Save Performance

# %%
model_name = 'BOW'
models_dict[model_name] = '/content/bow.h5'

train_loss, train_accuracy = model.evaluate(X_train, y_train)
validation_loss, validation_accuracy = model.evaluate(X_validation, y_validation)

evaluation = pd.DataFrame({
                          'Model' : [model_name],
                          'Train' : [train_accuracy],
                          'Validation' : [validation_accuracy]
                        })

evaluation_df = pd.concat([evaluation_df, evaluation], ignore_index=True)
# Out:
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0364 - accuracy: 0.9913
# 48/48 [==============================] - 0s 6ms/step - loss: 0.7178 - accuracy: 0.7518

# %% [markdown]
# <a id="6.2"></a> <br>
#
# ## 6.2 BOW Vectors

# %% [markdown]
# <a id="6.2.1"></a> <br>
#
# ##### Text Preparation for BOW Vectors

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_clean)
vocab_size = len(tokenizer.word_index) + 1

# %%
# integer encode the documents
train_encoded_docs = tokenizer.texts_to_sequences(X_train_clean)
validation_encoded_docs = tokenizer.texts_to_sequences(X_validation_clean)

# %%
print(train_encoded_docs)
# Out:
# [[7, 1074, 1075, 93, 1148, 1076, 32, 1733, 1149, 991, 104, 3203, 4709, 4710], [45, 6, 48, 2478, 66, 2, 30, 31, 107, 124, 710, 30, 64, 270], [3204, 114, 143, 137, 3, 762, 198, 3205], [3206, 308, 642, 369, 3207, 19, 450, 4711], [125, 9, 125, 9, 37, 862, 474, 198, 9, 475, 26, 49, 608], [2, 72, 17, 4712, 923, 105, 4713, 1517, 510], [149, 4714, 1518, 5, 60, 1371, 3208], [430, 4715, 4716, 144, 76, 67, 4717, 1245, 809, 451, 223], [67, 4718, 1519, 2024, 476, 643, 279, 130, 4719, 4720], [763, 3209, 38, 255, 496], [4721, 1734, 4722, 87, 70, 4723, 4724], [62, 115, 121, 80, 15, 224, 1735, 1372, 138, 242, 88, 1736, 452, 1520], [3210, 863, 4725, 2025, 3211, 810, 4726], [4727], [431, 577, 2479, 256, 292, 43, 8, 4728, 4729], [643, 644, 679, 432, 165, 344, 924, 4730], [4731, 4732, 4733, 433, 2026, 4734, 2026, 3212, 1246, 680, 4735, 3213, 811, 4736, 215], [166, 166, 6, 370, 4737, 91, 4738, 4739], [175, 280, 26, 711, 2027, 2480, 167, 188, 3214, 1150, 91], [812, 199, 1247, 925, 681, 324, 4740, 4741], [4742, 94, 813, 992, 4743, 1248, 764, 2481, 309, 1737, 20, 4744], [71, 645, 150, 4745, 4746, 126, 4747, 2028, 4748], [7, 406, 453, 814, 578, 993, 646, 1151, 994, 189, 26, 49, 77, 2482, 4749], [60, 4750, 1077, 260, 4751], [248, 25, 32, 168, 1152, 190, 4752, 4753], [1521, 1373, 190, 1078, 371, 1738, 372, 68, 11, 39, 2483, 4754], [176, 4755, 2029, 224, 4756, 4757, 1739, 682, 4758, 3215, 579, 815, 85, 4759], [3216, 647, 116, 2030, 3217, 3218, 3219, 3220, 511, 91], [4760, 2484, 202, 155, 3221, 25, 4761], [454, 233, 712, 124, 55, 1153], [4762, 158, 2031, 2485, 2032, 546, 28, 4763, 4764], [2, 72, 
_ = sns.countplot(x=list(map(len, train_encoded_docs)), ax=subplots[0])
_ = sns.kdeplot(list(map(len, train_encoded_docs)), fill=True, ax=subplots[1])

# %%
from statistics import mode
train_encoded_docs_length = list(map(len, train_encoded_docs))
mode(train_encoded_docs_length)
# Out:
# 12

# %% [markdown]
# As we see the most frequent value in the histogram (mode) = 12.

# %% [markdown]
# If we set the max padding length to be equal to the most frequent value in the histogram (mode = 12), let's see how many sentences we can get rid of.

# %%
len(list(filter(lambda x: x>=mode(train_encoded_docs_length), train_encoded_docs_length)))
# Out:
# 2106

# %%
len(train_encoded_docs_length)
# Out:
# 6090

# %% [markdown]
# We will lose around 34% of the data (6090 tweets).

# %%
round(len(list(filter(lambda x: x>=mode(train_encoded_docs_length), train_encoded_docs_length))) / len(train_encoded_docs_length)*100, 2)
# Out:
# 34.58

# %% [markdown]
# That's why we will set the max padding length to be equal to the length of the longest tweet.

# %%
max(train_encoded_docs_length)
# Out:
# 23

# %%
max_length = max(train_encoded_docs_length)
train_padded_docs = pad_sequences(train_encoded_docs, maxlen=max_length, padding='post')
validation_padded_docs = pad_sequences(validation_encoded_docs, maxlen=max_length, padding='post')

# %%
print(train_padded_docs)
# Out:
# [[    7  1074  1075 ...     0     0     0]
#  [   45     6    48 ...     0     0     0]
#  [ 3204   114   143 ...     0     0     0]
#  ...
#  [  599   173   246 ...     0     0     0]
#  [16194    56    93 ...     0     0     0]
#  [    6   255   488 ...     0     0     0]]

# %% [markdown]
# <a id="6.2.2"></a> <br>
#
# ##### Building Model

# %%
c_latent_factors = 32

model = models.Sequential()
model.add(layers.Embedding(vocab_size+1, c_latent_factors, input_length=max_length))
model.add(layers.Flatten())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 23, 32)            518304
#
#  flatten (Flatten)           (None, 736)               0
#
#  dense_3 (Dense)             (None, 16)                11792
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 530,385
# Trainable params: 530,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model)

# %%
from keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_padded_docs,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(validation_padded_docs, y_validation))
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 46ms/step - loss: 0.6754 - accuracy: 0.5708 - val_loss: 0.6582 - val_accuracy: 0.5791
# Epoch 2/20
# 12/12 [==============================] - 0s 19ms/step - loss: 0.6123 - accuracy: 0.6911 - val_loss: 0.6213 - val_accuracy: 0.6612
# Epoch 3/20
# 12/12 [==============================] - 0s 20ms/step - loss: 0.5126 - accuracy: 0.8338 - val_loss: 0.5616 - val_accuracy: 0.7439
# Epoch 4/20
# 12/12 [==============================] - 0s 19ms/step - loss: 0.3977 - accuracy: 0.8982 - val_loss: 0.5420 - val_accuracy: 0.7538
# Epoch 5/20
# 12/12 [==============================] - 0s 20ms/step - loss: 0.2972 - accuracy: 0.9271 - val_loss: 0.5147 - val_accuracy: 0.7669
# Epoch 6/20
# 12/12 [==============================] - 0s 20ms/step - loss: 0.2171 - accuracy: 0.9489 - val_loss: 0.5157 - val_accuracy: 0.7643
# Epoch 7/20
# 12/12 [==============================] - 0s 21ms/step - loss: 0.1562 - accuracy: 0.9596 - val_loss: 0.5285 - val_accuracy: 0.7708
# Epoch 8/20
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1147 - accuracy: 0.9693 - val_loss: 0.5395 - val_accuracy: 0.7649
# Epoch 9/20
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0827 - accuracy: 0.9787 - val_loss: 0.5657 - val_accuracy: 0.7689
# Epoch 10/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0618 - accuracy: 0.9837 - val_loss: 0.5939 - val_accuracy: 0.7682
# Epoch 11/20
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0480 - accuracy: 0.9864 - val_loss: 0.6247 - val_accuracy: 0.7689
# Epoch 12/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.6510 - val_accuracy: 0.7623
# Epoch 13/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0290 - accuracy: 0.9923 - val_loss: 0.7048 - val_accuracy: 0.7702
# Epoch 14/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.7456 - val_accuracy: 0.7315
# Epoch 15/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.8090 - val_accuracy: 0.7682
# Epoch 16/20
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.8445 - val_accuracy: 0.7649
# Epoch 17/20
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 0.9951 - val_loss: 0.8330 - val_accuracy: 0.7459
# Epoch 18/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0163 - accuracy: 0.9939 - val_loss: 0.8674 - val_accuracy: 0.7315
# Epoch 19/20
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0148 - accuracy: 0.9946 - val_loss: 0.8943 - val_accuracy: 0.7439
# Epoch 20/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.9642 - val_accuracy: 0.7571

# %% [markdown]
# <a id="6.2.3"></a> <br>
#
# ##### Training VS Validation

# %%
accuracy = history.history['accuracy']
loss = history.history['loss']

val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

plt.plot(accuracy, label='Training accuracy')
plt.plot(val_accuracy, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# <a id="6.2.4"></a> <br>
#
# ##### Save Model

# %%
model.save('/content/bow_vectors.h5')

# %% [markdown]
# <a id="6.2.5"></a> <br>
#
# ##### Save Performance

# %%
model_name = 'BOW Vectors'
models_dict[model_name] = '/content/bow_vectors.h5'

train_loss, train_accuracy = model.evaluate(train_padded_docs, y_train)
validation_loss, validation_accuracy = model.evaluate(validation_padded_docs, y_validation)

evaluation = pd.DataFrame({
                          'Model' : [model_name],
                          'Train' : [train_accuracy],
                          'Validation' : [validation_accuracy]
                        })

evaluation_df = pd.concat([evaluation_df, evaluation], ignore_index=True)
# Out:
# 191/191 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9962
# 48/48 [==============================] - 0s 2ms/step - loss: 0.9642 - accuracy: 0.7571

# %% [markdown]
# <a id="6.3"></a> <br>
#
# ## 6.3 LSTM

# %% [markdown]
# <a id="6.3.1"></a> <br>
#
# ##### Building Model

# %%
c_latent_factors = 32

model = models.Sequential()
model.add(layers.Embedding(vocab_size+1, c_latent_factors, input_length=max_length))
model.add(layers.LSTM(32, dropout=0.2, recurrent_dropout=0.4))
model.add(layers.Flatten())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 23, 32)            518304
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 527,441
# Trainable params: 527,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model)

# %%
from keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_padded_docs,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(validation_padded_docs, y_validation))
# Out:
# Epoch 1/20
# 12/12 [==============================] - 6s 193ms/step - loss: 0.6870 - accuracy: 0.5578 - val_loss: 0.6810 - val_accuracy: 0.5706
# Epoch 2/20
# 12/12 [==============================] - 2s 195ms/step - loss: 0.6399 - accuracy: 0.6213 - val_loss: 0.6155 - val_accuracy: 0.7137
# Epoch 3/20
# 12/12 [==============================] - 1s 117ms/step - loss: 0.4399 - accuracy: 0.8461 - val_loss: 0.5437 - val_accuracy: 0.7472
# Epoch 4/20
# 12/12 [==============================] - 1s 114ms/step - loss: 0.3161 - accuracy: 0.8890 - val_loss: 0.5519 - val_accuracy: 0.7551
# Epoch 5/20
# 12/12 [==============================] - 1s 114ms/step - loss: 0.2489 - accuracy: 0.9130 - val_loss: 0.5929 - val_accuracy: 0.7748
# Epoch 6/20
# 12/12 [==============================] - 1s 114ms/step - loss: 0.1945 - accuracy: 0.9338 - val_loss: 0.6608 - val_accuracy: 0.7781
# Epoch 7/20
# 12/12 [==============================] - 1s 115ms/step - loss: 0.1538 - accuracy: 0.9484 - val_loss: 0.7214 - val_accuracy: 0.7610
# Epoch 8/20
# 12/12 [==============================] - 1s 113ms/step - loss: 0.1316 - accuracy: 0.9576 - val_loss: 0.7112 - val_accuracy: 0.7663
# Epoch 9/20
# 12/12 [==============================] - 1s 120ms/step - loss: 0.1010 - accuracy: 0.9690 - val_loss: 0.8394 - val_accuracy: 0.7669
# Epoch 10/20
# 12/12 [==============================] - 3s 223ms/step - loss: 0.0843 - accuracy: 0.9744 - val_loss: 0.9174 - val_accuracy: 0.7406
# Epoch 11/20
# 12/12 [==============================] - 2s 137ms/step - loss: 0.0715 - accuracy: 0.9778 - val_loss: 0.9529 - val_accuracy: 0.7590
# Epoch 12/20
# 12/12 [==============================] - 1s 115ms/step - loss: 0.0600 - accuracy: 0.9796 - val_loss: 1.0589 - val_accuracy: 0.7255
# Epoch 13/20
# 12/12 [==============================] - 1s 114ms/step - loss: 0.0536 - accuracy: 0.9829 - val_loss: 1.0996 - val_accuracy: 0.7006
# Epoch 14/20
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 1.0729 - val_accuracy: 0.7360
# Epoch 15/20
# 12/12 [==============================] - 1s 115ms/step - loss: 0.0422 - accuracy: 0.9854 - val_loss: 1.1349 - val_accuracy: 0.7413
# Epoch 16/20
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0336 - accuracy: 0.9888 - val_loss: 1.2357 - val_accuracy: 0.7354
# Epoch 17/20
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 1.3012 - val_accuracy: 0.7170
# Epoch 18/20
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 1.3383 - val_accuracy: 0.7406
# Epoch 19/20
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0275 - accuracy: 0.9897 - val_loss: 1.3946 - val_accuracy: 0.7452
# Epoch 20/20
# 12/12 [==============================] - 1s 115ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 1.4063 - val_accuracy: 0.7367

# %% [markdown]
# <a id="6.3.2"></a> <br>
#
# ##### Training VS Validation

# %%
accuracy = history.history['accuracy']
loss = history.history['loss']

val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

plt.plot(accuracy, label='Training accuracy')
plt.plot(val_accuracy, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# <a id="6.3.3"></a> <br>
#
# ##### Save Model

# %%
model.save('/content/lstm.h5')

# %% [markdown]
# <a id="6.3.4"></a> <br>
#
# ##### Save Performance

# %%
model_name = 'LSTM'
models_dict[model_name] = '/content/lstm.h5'

train_loss, train_accuracy = model.evaluate(train_padded_docs, y_train)
validation_loss, validation_accuracy = model.evaluate(validation_padded_docs, y_validation)

evaluation = pd.DataFrame({
                          'Model' : [model_name],
                          'Train' : [train_accuracy],
                          'Validation' : [validation_accuracy]
                        })

evaluation_df = pd.concat([evaluation_df, evaluation], ignore_index=True)
# Out:
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9961
# 48/48 [==============================] - 0s 6ms/step - loss: 1.4063 - accuracy: 0.7367

# %% [markdown]
# <a id="6.4"></a> <br>
#
# ## 6.4 GRU

# %% [markdown]
# <a id="6.4.1"></a> <br>
#
# ##### Building Model

# %%
c_latent_factors = 32

model = models.Sequential()
model.add(layers.Embedding(vocab_size+1, c_latent_factors, input_length=max_length))
model.add(layers.GRU(32, dropout=0.2, recurrent_dropout=0.4))
model.add(layers.Flatten())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 23, 32)            518304
#
#  gru (GRU)                   (None, 32)                6336
#
#  flatten_2 (Flatten)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 525,457
# Trainable params: 525,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model)

# %%
from keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_padded_docs,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(validation_padded_docs, y_validation))
# Out:
# Epoch 1/20
# 12/12 [==============================] - 5s 143ms/step - loss: 0.6873 - accuracy: 0.5591 - val_loss: 0.6832 - val_accuracy: 0.5706
# Epoch 2/20
# 12/12 [==============================] - 1s 97ms/step - loss: 0.6833 - accuracy: 0.5703 - val_loss: 0.6832 - val_accuracy: 0.5706
# Epoch 3/20
# 12/12 [==============================] - 1s 118ms/step - loss: 0.6830 - accuracy: 0.5703 - val_loss: 0.6828 - val_accuracy: 0.5706
# Epoch 4/20
# 12/12 [==============================] - 2s 173ms/step - loss: 0.6821 - accuracy: 0.5703 - val_loss: 0.6820 - val_accuracy: 0.5706
# Epoch 5/20
# 12/12 [==============================] - 1s 108ms/step - loss: 0.6625 - accuracy: 0.5703 - val_loss: 0.6208 - val_accuracy: 0.5712
# Epoch 6/20
# 12/12 [==============================] - 1s 94ms/step - loss: 0.5057 - accuracy: 0.7808 - val_loss: 0.5962 - val_accuracy: 0.7656
# Epoch 7/20
# 12/12 [==============================] - 2s 168ms/step - loss: 0.3904 - accuracy: 0.8757 - val_loss: 0.5556 - val_accuracy: 0.7551
# Epoch 8/20
# 12/12 [==============================] - 1s 96ms/step - loss: 0.3036 - accuracy: 0.8952 - val_loss: 0.5740 - val_accuracy: 0.7695
# Epoch 9/20
# 12/12 [==============================] - 1s 96ms/step - loss: 0.2461 - accuracy: 0.9141 - val_loss: 0.6059 - val_accuracy: 0.7695
# Epoch 10/20
# 12/12 [==============================] - 1s 98ms/step - loss: 0.2163 - accuracy: 0.9271 - val_loss: 0.6204 - val_accuracy: 0.7702
# Epoch 11/20
# 12/12 [==============================] - 1s 96ms/step - loss: 0.1768 - accuracy: 0.9433 - val_loss: 0.6279 - val_accuracy: 0.7695
# Epoch 12/20
# 12/12 [==============================] - 1s 95ms/step - loss: 0.1490 - accuracy: 0.9509 - val_loss: 0.7228 - val_accuracy: 0.7702
# Epoch 13/20
# 12/12 [==============================] - 2s 166ms/step - loss: 0.1237 - accuracy: 0.9609 - val_loss: 0.7722 - val_accuracy: 0.7538
# Epoch 14/20
# 12/12 [==============================] - 2s 144ms/step - loss: 0.1116 - accuracy: 0.9652 - val_loss: 0.7599 - val_accuracy: 0.7590
# Epoch 15/20
# 12/12 [==============================] - 1s 96ms/step - loss: 0.0902 - accuracy: 0.9744 - val_loss: 0.8147 - val_accuracy: 0.7617
# Epoch 16/20
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0724 - accuracy: 0.9782 - val_loss: 0.9341 - val_accuracy: 0.7531
# Epoch 17/20
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0638 - accuracy: 0.9824 - val_loss: 0.9741 - val_accuracy: 0.7636
# Epoch 18/20
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0598 - accuracy: 0.9816 - val_loss: 1.0357 - val_accuracy: 0.7663
# Epoch 19/20
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0590 - accuracy: 0.9816 - val_loss: 1.0273 - val_accuracy: 0.7603
# Epoch 20/20
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0456 - accuracy: 0.9859 - val_loss: 1.1177 - val_accuracy: 0.7511

# %% [markdown]
# <a id="6.4.2"></a> <br>
#
# ##### Training VS Validation

# %%
accuracy = history.history['accuracy']
loss = history.history['loss']

val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

plt.plot(accuracy, label='Training accuracy')
plt.plot(val_accuracy, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# <a id="6.4.3"></a> <br>
#
# ##### Save Model

# %%
model.save('/content/gru.h5')

# %% [markdown]
# <a id="6.4.4"></a> <br>
#
# ##### Save Performance

# %%
model_name = 'GRU'
models_dict[model_name] = '/content/gru.h5'

train_loss, train_accuracy = model.evaluate(train_padded_docs, y_train)
validation_loss, validation_accuracy = model.evaluate(validation_padded_docs, y_validation)

evaluation = pd.DataFrame({
                          'Model' : [model_name],
                          'Train' : [train_accuracy],
                          'Validation' : [validation_accuracy]
                        })

evaluation_df = pd.concat([evaluation_df, evaluation], ignore_index=True)
# Out:
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0284 - accuracy: 0.9910
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1177 - accuracy: 0.7511

# %% [markdown]
# <a id="7"></a> <br>
#
# # 7. Evaluation
# ([Go to top](#top))

# %%
evaluation_df
# Out:
#          Model     Train  Validation
# 0          BOW  0.991297    0.751806
# 1  BOW Vectors  0.996223    0.757058
# 2         LSTM  0.996059    0.736704
# 3          GRU  0.990969    0.751149

# %%
from keras.models import load_model

# Get best model according to validation score.
best_model = evaluation_df[evaluation_df['Validation'] == evaluation_df['Validation'].max()]['Model'].values[0]

# %%
best_model
# Out:
# 'BOW Vectors'

# %%
model = load_model(models_dict[best_model])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 23, 32)            518304
#
#  flatten (Flatten)           (None, 736)               0
#
#  dense_3 (Dense)             (None, 16)                11792
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 530,385
# Trainable params: 530,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <a id="8"></a> <br>
#
# # 8. Submission File Generation
# ([Go to top](#top))

# %%
test_data = pd.read_csv('/content/test.csv')
test_data.shape
# Out:
# (3263, 4)

# %%
test_data.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
# Text preprocessing utilized during training

test_data['clean text'] = test_data['text'].apply(normalize_text)
test_data.head()
# Out:
#    id keyword location                                               text  \
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                           clean text
# 0                          happen terrible car crash
# 1  hear earthquake different city stay safe everyone
# 2  forest fire spot pond goose flee across street...
# 3                  apocalypse light spokane wildfire
# 4                 typhoon soudelor kill china taiwan

# %%
# Get the appropriate preparation based on model

if best_model == 'BOW':
  X_test = vectorizer.transform(test_data['clean text'].values)
  X_test = X_test.toarray()

else:
  X_test = tokenizer.texts_to_sequences(test_data['clean text'].values)
  X_test = pad_sequences(X_test, maxlen=max_length, padding='post')

# %%
predictions = model.predict(X_test).round()
# Out:
# 102/102 [==============================] - 0s 2ms/step

# %%
submission = pd.read_csv('/content/sample_submission.csv')
submission['target'] = np.round(predictions).astype('int')
submission.head()
# Out:
#    id  target
# 0   0       1
# 1   2       0
# 2   3       1
# 3   9       0
# 4  11       1

# %%
submission.to_csv('/content/submission.csv', index=False)
